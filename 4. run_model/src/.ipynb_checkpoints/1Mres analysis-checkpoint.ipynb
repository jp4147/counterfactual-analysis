# %%
import configs as c

from timeit import default_timer as timer

from datetime import timedelta
from datetime import datetime

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import pickle
import scipy.stats as st

# %% [markdown]
# # Results

# %%
from model import microsim, counterfactual
import transition_matrix as tm
import model_functions as mf
from tqdm import tqdm

# %% [markdown]
# # 1M

# %%
cases = pd.read_csv('1M/sj120/cases.csv')
states_total = pd.read_csv('1M/sj120/states_total_1M.csv')

# %%
dt1, dt2, dt3, dt4, pcmort = mf.get_incidence(np.array(states_total), cases['dt1'], cases['dt2'], cases['dt3'], cases['dt4'], cases['pcmort'])

# %%
c.target_inc.index = list(c.age_range)
c.target_inc.plot()

plt.plot(list(c.age_range), dt1,'b--')
plt.plot(list(c.age_range), dt2, color = 'orange', linestyle= '--')
plt.plot(list(c.age_range), dt3, 'g--')
plt.plot(list(c.age_range), dt4, 'r--')
plt.legend(['t1', 't2', 't3', 't4'], fontsize=15)
plt.xticks(list(range(0,85,5)))
plt.ylabel('Incidence Rate', fontsize = 20)
plt.xlabel('Age', fontsize = 20)
plt.show()

# %%
plt.plot(c.age_group, c.target_pcmort.values, 'k')
plt.plot(c.age_group, mf.grouping(pcmort), 'k:')
plt.xticks(rotation = 60)
plt.ylabel('Mortality', fontsize = 20)
plt.xlabel('Age group', fontsize = 20)
plt.legend(['SEER data', 'simulated results'])
plt.show()

# %%
res36_after = {}
for it in tqdm(range(10)):
    res36_after[it] = pd.read_pickle(r'1M/sj36/res1M_after'+str(it)+'.pickle')
res36 = {}
res36[0] = {}
res36[0][0] = pd.read_pickle(r'1M/sj36/res1M_before0.pickle')
res36[1] = res36_after
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [10:04<00:00, 60.40s/it]

# %%
res36dm_after = {}
for it in tqdm(range(10)):
    res36dm_after[it] = pd.read_pickle(r'1M/sj36_dm/res1M_after'+str(it)+'.pickle')
res36dm = {}
res36dm[0] = {}
res36dm[0][0] = pd.read_pickle(r'1M/sj36_dm/res1M_before0.pickle')
res36dm[1] = res36dm_after
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [05:02<00:00, 30.23s/it]

# %%
res60_after = {}
for it in tqdm(range(10)):
    res60_after[it] = pd.read_pickle(r'1M/sj60/res1M_after'+str(it)+'.pickle')
res60 = {}
res60[0] = {}
res60[0][0] = pd.read_pickle(r'1M/sj60/res1M_before0.pickle')
res60[1] = res60_after
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [06:43<00:00, 40.31s/it]

# %%
test_months = [3, 6, 12, 24, 48, 60, 72, 84, 96, 108, 114, 120]

# %%
res120_after = {}
for it in tqdm(range(10)):
    res120_after[it] = {}
    for m in test_months:
        res120_after[it][m] = pd.read_pickle(r'1M/sj120/res1M_after'+str(it)+'_'+ str(m)+'m.pickle')
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████| 10/10 [20:53<00:00, 125.31s/it]

# %%
res120 = {}
res120[0] = {}
res120[0][0] = {}
for m in tqdm(test_months):
    res120[0][0][m] = pd.read_pickle(r'1M/sj120/res1M_before0'+'_'+ str(m)+'m.pickle')
res120[1] = res120_after
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 12/12 [03:09<00:00, 15.78s/it]

# %%
cohort36 = pd.read_pickle(r'1M/sj36/cohort1M_cf.pickle')
cohort36dm = pd.read_pickle(r'1M/sj36_dm/cohort1M_cf.pickle')

cohort60 = pd.read_pickle(r'1M/sj60/cohort1M_cf.pickle')
cohort120 = pd.read_pickle(r'1M/sj120/cohort1M_cf.pickle')

# %%
print(len(cohort36))
print(len(cohort36dm))
print(len(cohort60))
print(len(cohort120))
# Out:
# 9812
# 10686
# 10054
# 10406

# %%
def progression_time(record_all):
    pt = []
    for i in range(len(record_all)):
        u_duration, d_duration = [], []
        h = record_all[i]
        for ii in range(len(h)):
            if h[ii][0] == 'U':
                u_duration.append(ii)
            if h[ii][0] == 'D':
                d_duration.append(ii)
        pt.append(d_duration[0] - u_duration[0])
    return pt

# plt.hist(progression_time(cohort36dm), bins=50, alpha = 0.3, density = True, color = 'm')
# pd.Series(progression_time(cohort36dm)).plot(kind = 'kde', color = 'm')

plt.hist(progression_time(cohort36), bins=50, alpha = 0.3, density = True, color = 'k')
pd.Series(progression_time(cohort36)).plot(kind = 'kde', color = 'k')

plt.hist(progression_time(cohort60), bins=50, alpha = 0.3, density = True, color = 'r')
pd.Series(progression_time(cohort60)).plot(kind = 'kde', color = 'r')

plt.hist(progression_time(cohort120), bins=50, alpha = 0.3, density = True, color = 'g')
pd.Series(progression_time(cohort120)).plot(kind = 'kde', color = 'g')

plt.xlabel('sojourn time [months]', fontsize = 15)
plt.ylabel('populationi density', fontsize = 15)
plt.legend(['Cohort with sj 36m', 'Cohort with sj 60m', 'Cohort with sj 120m'], fontsize = 12)
plt.xlim([0,600])
plt.show()

# %%
np.min(progression_time(cohort120))
# Out:
# 1

# %%
pt = []
for i in range(len(cohort36)):
    u_duration, d_duration = [], []
    h = cohort36[i]
    for ii in range(len(h)):
        if h[ii][0] == 'U':
            u_duration.append(ii)
        if h[ii][0] == 'D':
            d_duration.append(ii)
    if (d_duration[0] - u_duration[0]) < 6:
        pt.append(i)

# %%
len(pt)/len(cohort36)*100
# Out:
# 2.5580921320831633

# %%
def detected_died(record_all):
    dect_age, died_age = [], []
    for i in range(len(record_all)):
        pcmort_duration, d_duration = [], []
        h = record_all[i]
        for ii in range(len(h)):
            if h[ii] == 'PCMORT':
                pcmort_duration.append(ii)
            if h[ii][0] == 'D':
                d_duration.append(ii)
        dect_age.append(ageATtime(d_duration[0]))
        died_age.append(ageATtime(pcmort_duration[0]))
    return dect_age, died_age

# %%
detecte_age36, died_age36 = detected_died(cohort36)

# %%
detecte_age60, died_age60 = detected_died(cohort60)
detecte_age120, died_age120 = detected_died(cohort120)

# %%
# plt.hist(detecte_age36, bins=50, alpha = 0.3, density = True, color = 'k')
# pd.Series(detecte_age36).plot(kind = 'kde', color = 'k')

plt.hist(died_age36 , bins=50, alpha = 0.3, density = True, color = 'r')
pd.Series(died_age36 ).plot(kind = 'kde', color = 'r')

# plt.hist(detecte_age60, bins=50, alpha = 0.3, density = True, color = 'g')
# pd.Series(detecte_age60).plot(kind = 'kde', color = 'g')

plt.hist(died_age36 , bins=50, alpha = 0.3, density = True, color = 'b')
pd.Series(died_age36 ).plot(kind = 'kde', color = 'b')

# plt.hist(detecte_age36, bins=50, alpha = 0.3, density = True, color = 'k')
# pd.Series(detecte_age36).plot(kind = 'kde', color = 'k')

plt.hist(died_age36 , bins=50, alpha = 0.3, density = True, color = 'g')
pd.Series(died_age36 ).plot(kind = 'kde', color = 'g')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
np.median(died_age36)
# Out:
# 72.41666666666666

# %%
np.median(died_age60)
# Out:
# 72.33333333333334

# %%
np.median(died_age120)
# Out:
# 72.16666666666666

# %%
count = 0
for i in cohort36:
    if 'PCMORT' in i:
        count += 1

# %%
count = 1
for i in test:
    if i>36:
        count += 1

# %%
count
# Out:
# 4887

# %%
9812/2
# Out:
# 4906.0

# %%
def ageATtime(idx):
    return (idx-1)/12+c.age_range[0]

def progression_time_byageGroup(record_all):
    pt20, pt30, pt40, pt50, pt60, pt70 = [], [], [], [], [], []
    pt={}
    for i in range(len(record_all)):
        u_duration, d_duration = [], []
        h = record_all[i]
        for ii in range(len(h)):
            if h[ii][0] == 'U':
                u_duration.append(ii)
            if h[ii][0] == 'D':
                d_duration.append(ii)
        if np.floor(ageATtime(d_duration[0])) == 20:
            pt20.append(d_duration[0] - u_duration[0])
        elif np.floor(ageATtime(d_duration[0])) == 30:
            pt30.append(d_duration[0] - u_duration[0])
        elif np.floor(ageATtime(d_duration[0])) == 40:
            pt40.append(d_duration[0] - u_duration[0])
        elif np.floor(ageATtime(d_duration[0])) == 50:
            pt50.append(d_duration[0] - u_duration[0])
        elif np.floor(ageATtime(d_duration[0])) == 60:
            pt60.append(d_duration[0] - u_duration[0])
        elif np.floor(ageATtime(d_duration[0])) == 70:
            pt70.append(d_duration[0] - u_duration[0])
    pt[20] = pt20
    pt[30] = pt30
    pt[40] = pt40
    pt[50] = pt50
    pt[60] = pt60
    pt[70] = pt70
    return pt

# %%
pt = progression_time_byageGroup(cohort36)
colors = ['m','b','g','r','k','m']
ageG = [40,50,60,70]
ii=0
for a in ageG:
    plt.hist(pt[a], bins=50, alpha = 0.2, density = True, color = colors[ii])
    pd.Series(pt[a]).plot(kind = 'kde', color = colors[ii])
    print(len(pt[a]))
    print(np.median(pt[a]))
    print(np.mean(pt[a]))
    ii += 1
plt.legend(['40s','50s','60s','70s'], fontsize = 12)
plt.xlim([0,200])
plt.xlabel('sojourn time [months]', fontsize = 15)
plt.ylabel('populationi density', fontsize = 15)
plt.show()
# Out:
# 15
# 25.0
# 30.4
# 80
# 22.0
# 33.175
# 195
# 43.0
# 42.48717948717949
# 342
# 31.0
# 33.58479532163743

# %%
pt = progression_time_byageGroup(cohort60)
colors = ['m','b','g','r','k','m']
ageG = [40,50,60,70]
ii=0
for a in ageG:
    plt.hist(pt[a], bins=50, alpha = 0.2, density = True, color = colors[ii])
    pd.Series(pt[a]).plot(kind = 'kde', color = colors[ii])
    print(len(pt[a]))
    print(np.median(pt[a]))
    ii += 1
plt.legend(['40s','50s','60s','70s'], fontsize = 12)
plt.xlim([0,200])
plt.xlabel('sojourn time [months]', fontsize = 15)
plt.ylabel('populationi density', fontsize = 15)
plt.show()
# Out:
# 23
# 59.0
# 39
# 51.0
# 250
# 59.0
# 395
# 41.0

# %%
pt = progression_time_byageGroup(cohort120)
colors = ['m','b','g','r','k','m']
ageG = [40,50,60,70]
ii=0
for a in ageG:
    plt.hist(pt[a], bins=50, alpha = 0.2, density = True, color = colors[ii])
    pd.Series(pt[a]).plot(kind = 'kde', color = colors[ii])
    print(len(pt[a]))
    print(np.median(pt[a]))
    ii += 1
plt.legend(['40s','50s','60s','70s'], fontsize = 12)
plt.xlim([0,200])
plt.xlabel('sojourn time [months]', fontsize = 15)
plt.ylabel('populationi density', fontsize = 15)
plt.show()
# Out:
# 37
# 74.0
# 96
# 93.5
# 293
# 82.0
# 354
# 78.0

# %%
print(np.mean(progression_time(cohort36)))
print(np.median(progression_time(cohort36)))
# Out:
# 41.51314716673461
# 36.0

# %%
print(np.mean(progression_time(cohort60)))
print(np.median(progression_time(cohort60)))
# Out:
# 64.02516411378556
# 55.0

# %%
print(np.mean(progression_time(cohort120)))
print(np.median(progression_time(cohort120)))
# Out:
# 106.22352488948684
# 93.0

# %%
testN36, testN60, testN120 = [], [], []
for i in test_months:
    testN36.append(len(res36[1][0][i]))
    testN60.append(len(res60[1][0][i]))
    testN120.append(len(res120[1][0][i]))

# %%
plt.plot(testN36, 'o')
plt.plot(testN60, 'o')
plt.plot(testN120, 'o')
plt.ylabel('number of cohort tested', fontsize = 15)
plt.xlabel('early detection at x months before', fontsize = 15)
plt.xticks(np.array(range(len(test_months))), test_months)
plt.legend(['mean sj time = 36 months', 'mean sj time = 60 months', 'mean sj time = 120 months'])
plt.show()

# %%
testN36dm= []
for i in test_months:
    testN36dm.append(len(res36dm[1][0][i]))

# %%
plt.plot(testN36, 'o')
plt.plot(testN36dm, 'bo')
plt.ylabel('number of cohort tested', fontsize = 15)
plt.xlabel('early detection at x months before', fontsize = 15)
plt.xticks(np.array(range(len(test_months))), test_months)
plt.legend(['mean sj time = 36 months', 'mean sj time = 36 months w/ dm'])
plt.show()

# %%
def cal_survival_lengths(test):
    months_survived, years_survived = [], []
    for h in test:
        d_duration = []
        for i in range(len(h)):
            if h[i][0] == 'D':
                d_duration.append(i)
        # print(mf.ageATtime(d_duration[0]))
        if h[-1] == 'PCMORT':
            diedage = mf.ageATtime(h.index('PCMORT'))
            index = h.index('PCMORT')
            # print('PCMORT at '+ str(mf.ageATtime(index)))
        elif h[-1] == 'ACMORT':
            diedage = mf.ageATtime(h.index('ACMORT'))
            index = h.index('ACMORT')
            # print('ACMORT at '+ str(mf.ageATtime(index)))
        else:
            diedage = 85
            index = len(h)
        years_survived.append(diedage - mf.ageATtime(d_duration[0]))
        # print('years_survived = ' + str(years_survived))
        # print('months_survived = ' + str(index - i))
        months_survived.append(index-d_duration[0])
    
    return months_survived, years_survived

# %%
iterN=10
def years_survived(res):
    years_survived_before, years_survived_after = {}, {}
    for i in test_months:
        years_survived_before[i] = []
        years_survived_after[i] = []
    for it in tqdm(range(iterN)):
        cf_before = res[0][0]
        cf_after = res[1][it]
        for i in test_months:
            mb, yb = cal_survival_lengths(cf_before[i])
            ma, ya = cal_survival_lengths(cf_after[i])

            years_survived_before[i].append(np.mean([i/12 for i in mb]))
            years_survived_after[i].append(np.mean([i/12 for i in ma]))
    return years_survived_before, years_survived_after

# %%
b,a = years_survived(res120)

# %%
res60[0].keys()
# Out:
# dict_keys([0])

# %%
res120[0].keys()
# Out:
# dict_keys([3, 6, 12, 24, 48, 60, 72, 84, 96, 108, 114, 120])

# %%
col = ['k', 'r', 'g', 'b']
ii=0
pos = [-5, 0, 5, 0]
for test in [res36, res60, res120]:
    years_survived_before, years_survived_after = years_survived(test)
    avg, ci = [],[]
    for i in test_months:
        avg_value = np.mean(years_survived_after[i])
        ci_up_down = st.t.interval(alpha=0.95, df=len(years_survived_after[i])-1, loc=np.mean(years_survived_after[i]), scale=st.sem(years_survived_after[i]))
        ci_up = ci_up_down[1]-avg_value
        ci_down = avg_value - ci_up_down[0]
        ci.append([ci_down, ci_up])
        avg.append(avg_value)
    y_errormin = [i[0] for i in ci]
    y_errormax = [i[1] for i in ci]
    y_error =[y_errormin, y_errormax]
    plt.errorbar(np.array(np.array(range(len(test_months)))+1)*100+pos[ii], avg, yerr =y_error, fmt ='o', color = col[ii], capsize = 12)
    plt.plot(pos[ii], np.mean(years_survived_before[3]), marker = 'o', color = col[ii], alpha = 0.8)
    ii += 1
plt.xticks([0]+list(np.array(np.array(range(len(test_months)))+1)*100), [0]+test_months)
plt.ylabel('avg. years survived', fontsize = 15)
plt.xlabel('early detection at x months before', fontsize = 15)
plt.legend(['sj 36m', 'sj 60m', 'sj 120m'], fontsize = 12)
plt.show()
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [01:53<00:00, 11.37s/it]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [02:47<00:00, 16.74s/it]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [04:10<00:00, 25.06s/it]

# %%
col = ['k', 'r', 'g', 'b']
ii=0
pos = [-5, 0, 5, 0]
for test in [res36, res36dm]:
    years_survived_before, years_survived_after = years_survived(test)
    avg, ci = [],[]
    for i in test_months:
        avg_value = np.mean(years_survived_after[i])
        ci_up_down = st.t.interval(alpha=0.95, df=len(years_survived_after[i])-1, loc=np.mean(years_survived_after[i]), scale=st.sem(years_survived_after[i]))
        ci_up = ci_up_down[1]-avg_value
        ci_down = avg_value - ci_up_down[0]
        ci.append([ci_down, ci_up])
        avg.append(avg_value)
    y_errormin = [i[0] for i in ci]
    y_errormax = [i[1] for i in ci]
    y_error =[y_errormin, y_errormax]
    plt.errorbar(np.array(np.array(range(len(test_months)))+1)*100+pos[ii], avg, yerr =y_error, fmt ='o', color = col[ii], capsize = 12)
    plt.plot(pos[ii], np.mean(years_survived_before[3]), marker = 'o', color = col[ii], alpha = 0.8)
    ii += 1
plt.xticks([0]+list(np.array(np.array(range(len(test_months)))+1)*100), [0]+test_months)
plt.ylabel('avg. years survived', fontsize = 15)
plt.xlabel('early detection at x months before', fontsize = 15)
plt.legend(['sj 36m', 'sj 36m w/ dm'], fontsize = 12)
plt.show()
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [02:26<00:00, 14.65s/it]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [03:01<00:00, 18.19s/it]

# %%
col = ['k', 'r', 'g', 'b']
ii=0
fig, ax = plt.subplots()
pos = [-5, 0, 5, 0]
for test in [res36, res60, res120]:
    years_survived_before, years_survived_after = years_survived(test)
    avg, ci = [],[]
    for i in test_months:
        avg_value = np.mean(years_survived_after[i])
        ci_up_down = st.t.interval(alpha=0.95, df=len(years_survived_after[i])-1, loc=np.mean(years_survived_after[i]), scale=st.sem(years_survived_after[i]))
        ci_up = ci_up_down[1]-avg_value
        ci_down = avg_value - ci_up_down[0]
        ci.append([ci_down, ci_up])
        avg.append(avg_value)
    y_errormin = [i[0] for i in ci]
    y_errormax = [i[1] for i in ci]
    y_error =[y_errormin, y_errormax]
    ax.plot(np.array(range(len(test_months)))+1, avg, color = col[ii])
    ax.fill_between(np.array(range(len(test_months)))+1, np.array(avg)-np.array(y_errormin), np.array(avg)+np.array(y_errormax), alpha=0.3, facecolor = col[ii])
    ii += 1

plt.xticks(np.array(range(len(test_months)))+1, test_months)
plt.ylabel('avg. years survived', fontsize = 15)
plt.xlabel('early detection at x months before', fontsize = 15)
plt.legend(['sj 36m', 'sj 60m', 'sj 120m'], fontsize = 12)
plt.show()
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [01:42<00:00, 10.28s/it]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [02:43<00:00, 16.32s/it]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [03:34<00:00, 21.47s/it]

# %%
from scipy.stats import f_oneway
years_survived_before, years_survived_after36 = years_survived(res36)
years_survived_before, years_survived_after60 = years_survived(res60)
years_survived_before, years_survived_after120 = years_survived(res120)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [01:48<00:00, 10.90s/it]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [02:51<00:00, 17.19s/it]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [04:01<00:00, 24.19s/it]

# %%
for i in test_months:
    test = f_oneway(years_survived_after36[i], years_survived_after60[i], years_survived_after120[i])
    print(i)
    print(test)
# Out:
# 3
# F_onewayResult(statistic=4.078629681039207, pvalue=0.028327493101408453)
# 6
# F_onewayResult(statistic=11.020670008015625, pvalue=0.00031682495537804393)
# 12
# F_onewayResult(statistic=77.42799659855336, pvalue=6.562781898441713e-12)
# 24
# F_onewayResult(statistic=134.1525063675449, pvalue=9.435279258112735e-15)
# 48
# F_onewayResult(statistic=121.59771531315889, pvalue=3.131538915057713e-14)
# 60
# F_onewayResult(statistic=91.92487604047713, pvalue=8.90787343068163e-13)
# 72
# F_onewayResult(statistic=38.74430007058835, pvalue=1.1640738128663511e-08)
# 84
# F_onewayResult(statistic=36.89755460433946, pvalue=1.8922482388581457e-08)
# 96
# F_onewayResult(statistic=33.768162511856765, pvalue=4.4960191740247006e-08)
# 108
# F_onewayResult(statistic=118.90816520088755, pvalue=4.108246681550876e-14)
# 114
# F_onewayResult(statistic=81.83874510588161, pvalue=3.462330750939836e-12)
# 120
# F_onewayResult(statistic=70.51232606551174, pvalue=1.9093047347377868e-11)

# %%
i=24
print(np.mean(years_survived_after36[i]))
print(np.mean(years_survived_after60[i]))
print(np.mean(years_survived_after120[i]))
# Out:
# 5.996988195535247
# 5.927929101531659
# 5.808796010163439

# %%
print(stats.ttest_ind(years_survived_after36[i], years_survived_after60[i], equal_var = False))
# Out:
# Ttest_indResult(statistic=6.2185828983706415, pvalue=1.0935658348165755e-05)

# %%
# test_months = [3]
iterN = 10
def overdiagnosis_number(res):
    overdiagnosisN = {}
    for i in test_months:
        overdiagnosisN[i] = []
    for it in range(iterN):
        cf_before_res = res[0][0]
        cf_after_res = res[1][it]
        for m in test_months:
            cf_before = cf_before_res[m]
            cf_after = cf_after_res[m]

            leadT_bias = []
            for i in range(len(cf_before)):
                idx_before = cf_before[i].index('PCMORT')
                diedage_before = mf.ageATtime(idx_before)
                if cf_after[i][-1] == 'PCMORT':
                    idx_after = cf_after[i].index('PCMORT')
                    diedage_after = mf.ageATtime(idx_after)
                elif cf_after[i][-1] == 'ACMORT':
                    idx_after = cf_after[i].index('ACMORT')
                    diedage_after = mf.ageATtime(idx_after)
                else:
                    diedage = 85
                    idx_after = len(cf_after[i])
                if idx_after <= idx_before:
                    leadT_bias.append(i)
            overdiagnosisN[m].append(len(leadT_bias)/len(cf_before))
    return overdiagnosisN

# %%
ii=0
for test in tqdm([res36, res60, res120]):
    avg, ci = [],[]
    for i in test_months:
        od = overdiagnosis_number(test)
        avg_value = np.mean(od[i])
        ci_up_down = st.t.interval(alpha=0.95, df=len(od[i])-1, loc=np.mean(od[i]), scale=st.sem(od[i]))
        ci_up = ci_up_down[1]-avg_value
        ci_down = avg_value - ci_up_down[0]
        ci.append([ci_down*100, ci_up*100])
        avg.append(avg_value*100)
    y_errormin = [i[0] for i in ci]
    y_errormax = [i[1] for i in ci]
    y_error =[y_errormin, y_errormax]
    plt.errorbar(np.array(np.array(range(len(test_months)))+1)*100+pos[ii], avg, yerr =y_error, fmt ='o', color = col[ii], capsize = 12)
    ii += 1

plt.xticks(np.array(np.array(range(len(test_months)))+1)*100, test_months)
plt.ylabel('overdiagnosis [%]', fontsize = 15)
plt.xlabel('early detection at x months before', fontsize = 15)
plt.legend(['sj 36m', 'sj 60m', 'sj 120m'], fontsize = 12)
plt.show()
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████| 3/3 [29:00<00:00, 580.17s/it]

# %%
from scipy.stats import f_oneway
o36 = overdiagnosis_number(res36)
o60 = overdiagnosis_number(res60)
o120 = overdiagnosis_number(res120)

# %%
for i in test_months:
    test = f_oneway(o36[i], o60[i], o120[i])
    print(str(i)+'month:'+str(test[1]))
# Out:
# 3month:0.37031655371216354
# 6month:0.898273542732656
# 12month:0.008131149860949961
# 24month:0.0006354733299503701
# 48month:0.001141425042955272
# 60month:0.017313325696609705
# 72month:0.17644865638431875
# 84month:0.07894782855806769
# 96month:0.8640249529402231
# 108month:0.4045070426347181
# 114month:0.27695638556743585
# 120month:0.16254800716360182

# %%
from scipy import stats

# %%
for i in [12, 24, 48, 60]:
    test36_60 = stats.ttest_ind(o36[i], o60[i], equal_var = False)
    test60_120 = stats.ttest_ind(o60[i], o120[i], equal_var = False)
    print(i)
    print(test36_60)
    print(test60_120)
# Out:
# 12
# Ttest_indResult(statistic=-3.109148634841111, pvalue=0.0065414949824850995)
# Ttest_indResult(statistic=0.5182337879209444, pvalue=0.6107164806292127)
# 24
# Ttest_indResult(statistic=-1.4269838017251362, pvalue=0.172219272627369)
# Ttest_indResult(statistic=-2.726643246195372, pvalue=0.013847001561940596)
# 48
# Ttest_indResult(statistic=-1.5452183868476659, pvalue=0.14820188149420305)
# Ttest_indResult(statistic=-4.021051472900759, pvalue=0.0008228384759218298)
# 60
# Ttest_indResult(statistic=-1.4788486781364176, pvalue=0.1623939932267995)
# Ttest_indResult(statistic=-2.066016929097685, pvalue=0.05476788126479603)

# %%
for i in test_months:
    test = f_oneway(o36[i], o60[i], o120[i])
    print(str(i)+'month:'+str(test[1]))
# Out:
# 0.37031655371216354

# %%
ii=0
fig, ax = plt.subplots()
for test in tqdm([res36, res60, res120]):
    avg, ci = [],[]
    for i in test_months:
        od = overdiagnosis_number(test)
        avg_value = np.mean(od[i])
        ci_up_down = st.t.interval(alpha=0.95, df=len(od[i])-1, loc=np.mean(od[i]), scale=st.sem(od[i]))
        ci_up = ci_up_down[1]-avg_value
        ci_down = avg_value - ci_up_down[0]
        ci.append([ci_down*100, ci_up*100])
        avg.append(avg_value*100)
    y_errormin = [i[0] for i in ci]
    y_errormax = [i[1] for i in ci]
    ax.plot(np.array(range(len(test_months)))+1, avg, color = col[ii])
    ax.fill_between(np.array(range(len(test_months)))+1, np.array(avg)-np.array(y_errormin), np.array(avg)+np.array(y_errormax), alpha=0.3, facecolor = col[ii])
    ii += 1

plt.xticks(np.array(range(len(test_months)))+1, test_months)
plt.ylabel('overdiagnosis [%]', fontsize = 15)
plt.xlabel('early detection at x months before', fontsize = 15)
plt.legend(['sj 36m', 'sj 60m', 'sj 120m'], fontsize = 12)
plt.show()
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████| 3/3 [27:48<00:00, 556.08s/it]

# %%
def months_gained(cf_before, cf_after):
    months_gained1, months_gained2 = [], []
    check=[]
    for i in range(len(cf_before)):
        idx_before = cf_before[i].index('PCMORT')
        diedage_before = mf.ageATtime(idx_before)
        if cf_after[i][-1] == 'PCMORT':
            idx_after = cf_after[i].index('PCMORT')
            diedage_after = mf.ageATtime(idx_after)
        elif cf_after[i][-1] == 'ACMORT':
            idx_after = cf_after[i].index('ACMORT')
            diedage_after = mf.ageATtime(idx_after)
        else:
            diedage = 85
            idx_after = len(cf_after[i])
        if i in leadT_bias:
            months_gained1.append(idx_after - idx_before)
            # if idx_after - idx_before < -120:
            #     check.append(i)
            # if cf_after[i][-1] == 'ACMORT':
            #     check.append(i)
        else:
            months_gained2.append(idx_after - idx_before)
        #     if idx_after - idx_before > 30*12:
        #         check.append(i)
    return np.array(months_gained1 + months_gained2)

# %%
def ageATtime(idx):
    return (idx-1)/12+c.age_range[0]

# %%
def res_df(res, month):

    pcmortAt, detected_stage, detectedAt, cf_stage, cf_age, diedAt, diedBy, yg = [], [], [], [], [], [], [], []
    stage_before_died = []

    for it in range(10):
        for case in range(len(res[1][it][month])):
            b = res[0][0][month][case]
            a = res[1][it][month][case]

            pcmortAt.append(ageATtime(b.index('PCMORT')))
            dts = b[b.index('PCMORT')-1]
            detected_stage.append(dts)
            detectedAt.append(ageATtime(b.index(dts)))
            cf_stage.append(b[b.index(dts)-month])
            cf_age.append(ageATtime(b.index(dts)-month))

            if a[-1]=='PCMORT':
                da = ageATtime(a.index('PCMORT'))
                stage_before_died.append(a[a.index('PCMORT')-1])
            elif a[-1]=='ACMORT':
                da = ageATtime(a.index('ACMORT'))
                stage_before_died.append(a[a.index('ACMORT')-1])
            else:
                da = 85
                stage_before_died.append(a[-1])

            diedAt.append(da)
            diedBy.append(a[-1])
            yg.append(da-ageATtime(b.index('PCMORT')))

        res_df = pd.DataFrame()
        res_df['pcmortAt'] = pcmortAt
        res_df['detected_stage'] = detected_stage
        res_df['detectedAt'] = detectedAt
        res_df['cf_stage'] = cf_stage
        res_df['cf_age'] = cf_age
        res_df['diedAt'] = diedAt
        res_df['diedBy'] = diedBy
        res_df['stage_before_died'] = stage_before_died
        res_df['years_gained'] = yg
    return res_df

# %%
ii=0
for test in tqdm([res36, res60, res120]):
    avg, ci = [],[]
    for m in test_months:
        y = res_df(test, m)['years_gained'].tolist()
        avg_value = np.mean(y)
        ci_up_down = st.t.interval(alpha=0.95, df=len(y)-1, loc=np.mean(y), scale=st.sem(y))
        ci_up = ci_up_down[1]-avg_value
        ci_down = avg_value - ci_up_down[0]
        ci.append([ci_down, ci_up])
        avg.append(avg_value)
    y_errormin = [i[0] for i in ci]
    y_errormax = [i[1] for i in ci]
    y_error =[y_errormin, y_errormax]
    plt.errorbar(np.array(range(len(test_months)))+1, avg, yerr =y_error, fmt ='o', color = col[ii], capsize = 12)
    ii += 1
plt.xticks(np.array(range(len(test_months)))+1, test_months)
plt.ylabel('avg. years gained', fontsize = 15)
plt.xlabel('early detection at x months before', fontsize = 15)
# plt.legend(['sj 36m', 'sj 60m', 'sj 120m', 'sj 1800m'], fontsize = 12)
plt.legend(['sj 36m', 'sj 60m', 'sj 120m'], fontsize = 12)

plt.show()
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████| 3/3 [04:42<00:00, 94.31s/it]

# %%
test = res_df(res36, 3)

# %%
test
# Out:
#         pcmortAt detected_stage  detectedAt cf_stage     cf_age     diedAt  \
# 0      58.750000            DT3   56.750000      UT3  56.500000  60.083333
# 1      66.333333            DT3   65.916667      UT3  65.666667  68.916667
# 2      70.666667            DT3   70.083333      UT3  69.833333  71.666667
# 3      69.333333            DT3   67.333333      UT3  67.083333  71.583333
# 4      82.916667            DT2   81.333333      UT1  81.083333  84.333333
# ...          ...            ...         ...      ...        ...        ...
# 97525  71.916667            DT3   67.583333      UT3  67.333333  75.583333
# 97526  67.750000            DT2   65.833333      UT2  65.583333  69.333333
# 97527  70.583333            DT3   67.750000      UT3  67.500000  70.750000
# 97528  59.333333            DT3   59.166667      UT3  58.916667  59.333333
# 97529  49.500000            DT3   49.333333      UT3  49.083333  49.583333
#
#        diedBy stage_before_died  years_gained
# 0      PCMORT               DT3      1.333333
# 1      PCMORT               DT3      2.583333
# 2      PCMORT               DT3      1.000000
# 3      PCMORT               DT3      2.250000
# 4      ACMORT               DT1      1.416667
# ...       ...               ...           ...
# 97525  PCMORT               DT3      3.666667
# 97526  PCMORT               DT2      1.583333
# 97527  PCMORT               DT3      0.166667
# 97528  PCMORT               DT3      0.000000
# 97529  PCMORT               DT3      0.083333
#
# [97530 rows x 9 columns]

# %%
ii=0
for test in tqdm([res36, res60, res120]):
    avg, ci = [],[]
    for m in test_months:
        survival_length = np.array(res_df(test, m)['diedAt']) - np.array(res_df(test, m)['cf_age'])
        avg_value = np.mean(survival_length)
        ci_up_down = st.t.interval(alpha=0.95, df=len(survival_length)-1, loc=np.mean(y), scale=st.sem(y))
        ci_up = ci_up_down[1]-avg_value
        ci_down = avg_value - ci_up_down[0]
        ci.append([ci_down, ci_up])
        avg.append(avg_value)
    y_errormin = [i[0] for i in ci]
    y_errormax = [i[1] for i in ci]
    y_error =[y_errormin, y_errormax]
    plt.errorbar(np.array(range(len(test_months)))+1, avg, yerr =y_error, fmt ='o', color = col[ii], capsize = 12)
    ii += 1
plt.xticks(np.array(range(len(test_months)))+1, test_months)
plt.ylabel('avg. years gained', fontsize = 15)
plt.xlabel('early detection at x months before', fontsize = 15)
# plt.legend(['sj 36m', 'sj 60m', 'sj 120m', 'sj 1800m'], fontsize = 12)
plt.legend(['sj 36m', 'sj 60m', 'sj 120m'], fontsize = 12)

plt.show()
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████| 3/3 [11:36<00:00, 232.00s/it]

# %%
ii=0
fig, ax = plt.subplots()
for test in tqdm([res36, res60, res120]):
    avg, ci = [],[]
    for m in test_months:
        y = res_df(test, m)['years_gained'].tolist()
        avg_value = np.mean(y)
        ci_up_down = st.t.interval(alpha=0.95, df=len(y)-1, loc=np.mean(y), scale=st.sem(y))
        ci_up = ci_up_down[1]-avg_value
        ci_down = avg_value - ci_up_down[0]
        ci.append([ci_down, ci_up])
        avg.append(avg_value)
    y_errormin = [i[0] for i in ci]
    y_errormax = [i[1] for i in ci]
    y_error =[y_errormin, y_errormax]
    ax.plot(np.array(range(len(test_months)))+1, avg, color = col[ii])
    ax.fill_between(np.array(range(len(test_months)))+1, np.array(avg)-np.array(y_errormin), np.array(avg)+np.array(y_errormax), alpha=0.3, facecolor = col[ii])
    ii += 1
plt.xticks(np.array(range(len(test_months)))+1, test_months)
plt.ylabel('avg. years gained', fontsize = 15)
plt.xlabel('early detection at x months before', fontsize = 15)
# plt.legend(['sj 36m', 'sj 60m', 'sj 120m', 'sj 1800m'], fontsize = 12)
plt.legend(['sj 36m', 'sj 60m', 'sj 120m'], fontsize = 12)

plt.show()
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████| 3/3 [04:17<00:00, 85.67s/it]

# %%
np.array(avg)-np.array(y_errormin)
# Out:
# array([1.80004439, 1.84948879, 1.90057265, 1.99040798, 2.09701554,
#        2.12177848, 2.14495587, 2.16884886, 2.18537409, 2.20477549,
#        2.23569747, 2.193841  ])

# %%
        ax.plot(epochs, meanst, label=means.ix[i]["label"], c=clrs[i])
        ax.fill_between(epochs, meanst-sdt, meanst+sdt ,alpha=0.3, facecolor=clrs[i])

# %%
y36, y60, y120={}, {}, {}
for m in tqdm(test_months):
    y36[m] = res_df(res36, m)['years_gained'].tolist()
    y60[m] = res_df(res60, m)['years_gained'].tolist()
    y120[m] = res_df(res120, m)['years_gained'].tolist()
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 12/12 [07:19<00:00, 36.61s/it]

# %%
from scipy import stats

# %%
def sig_change(y):
    for i in range(len(test_months)-1):
        print(str(test_months[i])+' vs '+str(test_months[i+1]))
        print(stats.ttest_ind(y[test_months[i]], y[test_months[i+1]], equal_var = False))

# %%
sig_change(y60)
# Out:
# 3 vs 6
# Ttest_indResult(statistic=-8.26103744005295, pvalue=1.4528774697290622e-16)
# 6 vs 12
# Ttest_indResult(statistic=-10.448320091890825, pvalue=1.5153231831209586e-25)
# 12 vs 24
# Ttest_indResult(statistic=-11.35104093144565, pvalue=7.509802921497125e-30)
# 24 vs 48
# Ttest_indResult(statistic=-11.611658615985286, pvalue=3.7372161890698342e-31)
# 48 vs 60
# Ttest_indResult(statistic=-1.1637506956268235, pvalue=0.2445278784906068)
# 60 vs 72
# Ttest_indResult(statistic=-3.979101132853021, pvalue=6.924039244160946e-05)
# 72 vs 84
# Ttest_indResult(statistic=2.4763636382402807, pvalue=0.013275593499267295)
# 84 vs 96
# Ttest_indResult(statistic=1.7603280448808332, pvalue=0.07835902960768953)
# 96 vs 108
# Ttest_indResult(statistic=-3.590108336011847, pvalue=0.00033104928182277945)
# 108 vs 114
# Ttest_indResult(statistic=0.12204397249493637, pvalue=0.9028651078001703)
# 114 vs 120
# Ttest_indResult(statistic=1.8271061573532295, pvalue=0.06769677074440887)

# %% [markdown]
# # find patients who was detected 56

# %%
def ageATtime(idx):
    return (idx-1)/12+c.age_range[0]

# %%
def res_df(res, month):

    pcmortAt, detected_stage, detectedAt, cf_stage, cf_age, diedAt, diedBy, yg = [], [], [], [], [], [], [], []
    stage_before_died = []

    for it in range(10):
        for case in range(len(res[1][it][month])):
            b = res[0][0][month][case]
            a = res[1][it][month][case]

            pcmortAt.append(ageATtime(b.index('PCMORT')))
            dts = b[b.index('PCMORT')-1]
            detected_stage.append(dts)
            detectedAt.append(ageATtime(b.index(dts)))
            cf_stage.append(b[b.index(dts)-month])
            cf_age.append(ageATtime(b.index(dts)-month))

            if a[-1]=='PCMORT':
                da = ageATtime(a.index('PCMORT'))
                stage_before_died.append(a[a.index('PCMORT')-1])
            elif a[-1]=='ACMORT':
                da = ageATtime(a.index('ACMORT'))
                stage_before_died.append(a[a.index('ACMORT')-1])
            else:
                da = 85
                stage_before_died.append(a[-1])

            diedAt.append(da)
            diedBy.append(a[-1])
            yg.append(da-ageATtime(b.index('PCMORT')))

        res_df = pd.DataFrame()
        res_df['pcmortAt'] = pcmortAt
        res_df['detected_stage'] = detected_stage
        res_df['detectedAt'] = detectedAt
        res_df['cf_stage'] = cf_stage
        res_df['cf_age'] = cf_age
        res_df['diedAt'] = diedAt
        res_df['diedBy'] = diedBy
        res_df['stage_before_died'] = stage_before_died
        res_df['years_gained'] = yg
    return res_df

# %%
def cfQ(res, detected_age, detected_stage):
    database = {}
    for m in test_months:
        chart = res_df(res, m)
        
        selected_chart = []
        for i, row in chart.iterrows():
            if np.floor(row['detectedAt']) == detected_age:
                if row['detected_stage']==detected_stage:
                    selected_chart.append(row)
        database[m] = pd.DataFrame(selected_chart)
    return database

# %%
def cfQ_byGen(res, detected_age, detected_stage):
    database = {}
    for m in test_months:
        chart = res_df(res, m)
        
        selected_chart = []
        for i, row in chart.iterrows():
            if row['detectedAt'] < detected_age+10:
                if row['detectedAt'] >= detected_age:
                    if row['detected_stage']==detected_stage:
                        selected_chart.append(row)
        database[m] = pd.DataFrame(selected_chart)
    return database

# %%
dat = cfQ(res36, 56, 'DT4')

# %%
# count = 0
# for case in cohort[1]:
#     if 'DT4' in case:
#         if np.floor(ageATtime(case.index('DT4'))) == 56:
#             count += 1

# %%
for m in test_months:
    print(str(m)+'months ealier: '+str(len(dat[m])))
# Out:
# 3months ealier: 750
# 6months ealier: 750
# 12months ealier: 700
# 24months ealier: 460
# 48months ealier: 300
# 60months ealier: 120
# 72months ealier: 20
# 84months ealier: 20
# 96months ealier: 10
# 108months ealier: 0
# 114months ealier: 0
# 120months ealier: 0

# %%
col = ['k','r','g','b']
ii=0
legend = ['sj 36m', 'sj 60m', 'sj 120m']
for d in tqdm([res36, res60, res120]):
    dat = cfQ(d, 24, 'DT4')
    avg, ci = [], []
    for m in test_months:
        if len(dat[m])>0:
            y = dat[m]['years_gained']
            avg_value = np.mean(y)
            ci_up_down = st.t.interval(alpha=0.95, df=len(y)-1, loc=np.mean(y), scale=st.sem(y))
            ci_up = ci_up_down[1]-avg_value
            ci_down = avg_value - ci_up_down[0]
            ci.append([ci_down, ci_up])
            avg.append(avg_value)
    y_errormin = [i[0] for i in ci]
    y_errormax = [i[1] for i in ci]
    y_error =[y_errormin, y_errormax]
    plt.errorbar(np.array(range(len(avg)))+1, avg, yerr =y_error, fmt ='o', color = col[ii], capsize = 12)
    ii += 1
plt.xticks(np.array(range(len(test_months)))+1, test_months)
plt.ylabel('avg. years gained', fontsize = 15)
plt.xlabel('early detection at x months before', fontsize = 15)
plt.legend(['sj 36m', 'sj 60m', 'sj 120m'], fontsize = 12)
# plt.legend(['sj 120m'], fontsize = 12)
plt.ylim([-0.5, 10.1])
plt.show()
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████| 3/3 [05:47<00:00, 115.73s/it]

# %%
def plot_yg(datf):
    legend = ['sj 36m', 'sj 60m', 'sj 120m']
    ii=0
    fig = plt.figure(figsize = (16,4))
    sj_test = [36, 60, 120]
    for d in tqdm(sj_test):
        plt.subplot(1, 3, ii+1)
        dat = datf[d]
        avg, ci = [], []
        for m in test_months:
            if len(dat[m])>0:
                y = dat[m]['years_gained']
                avg_value = np.mean(y)
                ci_up_down = st.t.interval(alpha=0.95, df=len(y)-1, loc=np.mean(y), scale=st.sem(y))
                ci_up = ci_up_down[1]-avg_value
                ci_down = avg_value - ci_up_down[0]
                ci.append([ci_down, ci_up])
                avg.append(avg_value)
        y_errormin = [i[0] for i in ci]
        y_errormax = [i[1] for i in ci]
        y_error =[y_errormin, y_errormax]
        plt.errorbar(np.array(range(len(avg)))+1, avg, yerr =y_error, fmt ='o', color = 'k', capsize = 12)

        plt.xticks(np.array(range(len(test_months)))+1, test_months)
        plt.ylabel('avg. years gained', fontsize = 15)
        plt.xlabel('early detection at x months before', fontsize = 15)
        plt.legend([legend[ii]], fontsize = 12)
        plt.ylim([-0.5, 25])
        plt.xlim([0, 13])
        ii += 1
    plt.tight_layout()

# %%
dat20, dat30, dat40, dat50, dat60, dat70 = {}, {}, {}, {}, {}, {}
sj_test = [36, 60, 120]
ii=0
for d in tqdm([res36, res60, res120]):
    dat20[sj_test[ii]] = cfQ_byGen(d, 20, 'DT4')
    dat30[sj_test[ii]] = cfQ_byGen(d, 30, 'DT4')
    dat40[sj_test[ii]] = cfQ_byGen(d, 40, 'DT4')
    dat50[sj_test[ii]] = cfQ_byGen(d, 50, 'DT4')
    dat60[sj_test[ii]] = cfQ_byGen(d, 60, 'DT4')
    dat70[sj_test[ii]] = cfQ_byGen(d, 70, 'DT4')
    ii += 1
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████| 3/3 [46:38<00:00, 932.97s/it]

# %%
dat1, dat2, dat3, dat4 = {}, {}, {}, {}

sj_test = [36, 60, 120]
ii=0
for d in tqdm([res36, res60, res120]):
    dat1[sj_test[ii]] = cfQ(d, 56, 'DT4')
    dat2[sj_test[ii]] = cfQ(d, 56, 'DT3')
    dat3[sj_test[ii]] = cfQ(d, 36, 'DT4')
    dat4[sj_test[ii]] = cfQ(d, 24, 'DT4')

    ii += 1
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████| 3/3 [17:10<00:00, 343.35s/it]

# %%
dat54_DT4 = {}
dat54_DT3 = {}
dat54_DT2 = {}
dat54_DT1 = {}

dat67_DT4 = {}
dat67_DT3 = {}
dat67_DT2 = {}
dat67_DT1 = {}

sj_test = [36, 60, 120]
ii=0
for d in tqdm([res36, res60, res120]):
    dat54_DT4[sj_test[ii]] = cfQ(d, 54, 'DT4')
    dat54_DT3[sj_test[ii]] = cfQ(d, 54, 'DT3')
    dat54_DT2[sj_test[ii]] = cfQ(d, 54, 'DT2')
    dat54_DT1[sj_test[ii]] = cfQ(d, 54, 'DT1')
    
    dat67_DT4[sj_test[ii]] = cfQ(d, 67, 'DT4')
    dat67_DT3[sj_test[ii]] = cfQ(d, 67, 'DT3')
    dat67_DT2[sj_test[ii]] = cfQ(d, 67, 'DT2')
    dat67_DT1[sj_test[ii]] = cfQ(d, 67, 'DT1')

    ii += 1
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 3/3 [52:06<00:00, 1042.11s/it]

# %%
plot_yg(dat70)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 25.26it/s]

# %%
for m in test_months:
    print(str(m)+'months ealier: '+str(len(dat1[36][m])))
# Out:
# 3months ealier: 5480
# 6months ealier: 5480
# 12months ealier: 5450
# 24months ealier: 5150
# 48months ealier: 3020
# 60months ealier: 1970
# 72months ealier: 1170
# 84months ealier: 640
# 96months ealier: 350
# 108months ealier: 140
# 114months ealier: 100
# 120months ealier: 60

# %%
avg, ci = [], []
dat = dat20[36]
# fig, ax = plt.subplots()
ii=0
for m in test_months:
    if len(dat[m])>0:
        y = dat[m]['years_gained']
        avg_value = np.mean(y)
        ci_up_down = st.t.interval(alpha=0.95, df=len(y)-1, loc=np.mean(y), scale=st.sem(y))
        ci_up = ci_up_down[1]-avg_value
        ci_down = avg_value - ci_up_down[0]
        ci.append([ci_down, ci_up])
        avg.append(avg_value)
y_errormin = [i[0] for i in ci]
y_errormax = [i[1] for i in ci]
y_error =[y_errormin, y_errormax]
plt.plot(np.array(range(len(avg)))+1, avg, color = 'k')
plt.fill_between(np.array(range(len(avg)))+1, np.array(avg)-np.array(y_errormin), np.array(avg)+np.array(y_errormax), alpha=0.3, facecolor = col[ii])

# %%
# color = ['darkblue', 'blue', 'royalblue', 'cornflowerblue', 'slategray', 'lightsteelblue']
color = ['k', 'r', 'g', 'b', 'm', 'cyan']

def plot_yg3(lst):
    legend = ['sj 36m', 'sj 60m', 'sj 120m']
    fig = plt.figure(figsize = (16,4))
    sj_test = [36, 60, 120]
    ii=0
    for d in tqdm(sj_test):
        col=0
        plt.subplot(1, 3, ii+1)
        for datf in lst:
            dat = datf[d]
            avg, ci = [], []
            for m in test_months:
                if len(dat[m])>0:
                    y = dat[m]['years_gained']
                    avg_value = np.mean(y)
                    ci_up_down = st.t.interval(alpha=0.95, df=len(y)-1, loc=np.mean(y), scale=st.sem(y))
                    ci_up = ci_up_down[1]-avg_value
                    ci_down = avg_value - ci_up_down[0]
                    ci.append([ci_down, ci_up])
                    avg.append(avg_value)
            y_errormin = [i[0] for i in ci]
            y_errormax = [i[1] for i in ci]
            y_error =[y_errormin, y_errormax]
            plt.plot(np.array(range(len(avg)))+1, avg, color = color[col])
            plt.fill_between(np.array(range(len(avg)))+1, np.array(avg)-np.array(y_errormin), np.array(avg)+np.array(y_errormax), alpha=0.3, facecolor = color[col])
            col += 1
        plt.legend(['20s','30s','40s','50s','60s','70s'])

        plt.xticks(np.array(range(len(test_months)))+1, test_months)
        plt.ylabel('avg. years gained', fontsize = 15)
        plt.xlabel('early detection at x months before', fontsize = 15)
        plt.title(legend[ii], fontsize = 12)
        
        plt.ylim([-0.5, 25])
        plt.xlim([0, 13])
        ii += 1
    plt.tight_layout()

# %%
plot_yg3([dat20, dat30, dat40, dat50, dat60, dat70])
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 14.64it/s]

# %%
# color = ['darkblue', 'blue', 'royalblue', 'cornflowerblue', 'slategray', 'lightsteelblue']
color = ['k', 'r', 'g', 'b', 'm', 'cyan']

def plot_yg_ind(datf, s, a):
    legend = ['sj 36m', 'sj 60m', 'sj 120m']
    # fig = plt.figure(figsize = (6,4))
    sj_test = [36, 60, 120]
    ii=0
    col=0
    for d in tqdm(sj_test):
        # plt.subplot(1, 3, ii+1)
        dat = datf[d]
        avg, ci = [], []
        for m in test_months:
            if len(dat[m])>0:
                y = dat[m]['years_gained']
                avg_value = np.mean(y)
                ci_up_down = st.t.interval(alpha=0.95, df=len(y)-1, loc=np.mean(y), scale=st.sem(y))
                ci_up = ci_up_down[1]-avg_value
                ci_down = avg_value - ci_up_down[0]
                ci.append([ci_down, ci_up])
                avg.append(avg_value)
        y_errormin = [i[0] for i in ci]
        y_errormax = [i[1] for i in ci]
        y_error =[y_errormin, y_errormax]
        plt.plot(np.array(range(len(avg)))+1, avg, color = color[col])
        plt.fill_between(np.array(range(len(avg)))+1, np.array(avg)-np.array(y_errormin), np.array(avg)+np.array(y_errormax), alpha=0.3, facecolor = color[col])
        col += 1

        plt.xticks(np.array(range(len(test_months)))+1, test_months)
        plt.ylabel('avg. years gained', fontsize = 15)
        plt.xlabel('early detection at x months before', fontsize = 15)
        plt.legend(legend, fontsize = 12)
        plt.title('patient diagnosed stage '+ s + ' at age '+ str(a), fontsize = 15)
        
        # plt.ylim([0, 8])
        # plt.xlim([0, 13])
        ii += 1
    plt.tight_layout()

# %%
plot_yg_ind(dat54_DT3, 'III', 54)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 51.95it/s]

# %%
plot_yg_ind(dat67_DT3, 'III', 67)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 54.79it/s]

# %%
plot_yg_ind(dat67_DT4, 'IV', 67)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 52.86it/s]

# %%
plot_yg_ind(dat1)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 52.86it/s]

# %%
s36, s60, s120 = {}, {}, {}
for m in tqdm(test_months):
    s36[m] = res_df(res36, m)
    s60[m] = res_df(res60, m)
    s120[m] = res_df(res120, m)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 12/12 [05:22<00:00, 26.85s/it]

# %%
def draw_hist(df, col, color):
    plt.hist(df[col], bins=20, alpha = 0.3, density = True, color = color)
    pd.Series(df[col]).plot(kind = 'kde', color = color)

# %%
var = 'pcmortAt'
fig = plt.figure(figsize = (20,10))
fig.subplots_adjust(hspace=0.4, wspace=0.4)

for i in tqdm(range(len(test_months))):
    plt.subplot(3, 4, i+1)
    
    draw_hist(s36[test_months[i]], var, 'k')
    draw_hist(s60[test_months[i]], var, 'r')
    draw_hist(s120[test_months[i]], var, 'g')
    
    m36 = round(np.median(s36[test_months[i]][var])*100)/100
    m60 = round(np.median(s60[test_months[i]][var])*100)/100
    m120 = round(np.median(s120[test_months[i]][var])*100)/100
    
    plt.title(str(test_months[i])+' months earlier'+'('+str(m36)+', '+str(m60)+', '+str(m120)+ ')')
    
    plt.xlabel('cancer death age', fontsize = 15)
    plt.ylabel('population density', fontsize = 15)
    # plt.legend(['sj 36m', 'sj 60m', 'sj 120m'], fontsize = 12)
    
plt.tight_layout()
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 12/12 [00:50<00:00,  4.22s/it]

# %%
var = 'pcmortAt'
fig = plt.figure(figsize = (20,10))
fig.subplots_adjust(hspace=0.4, wspace=0.4)

for i in tqdm(range(len(test_months))):
    plt.subplot(3, 4, i+1)
    
    draw_hist(s36[test_months[i]], var, 'k')
    draw_hist(s60[test_months[i]], var, 'r')
    draw_hist(s120[test_months[i]], var, 'g')
    
    m36 = round(np.median(s36[test_months[i]][var])*100)/100
    m60 = round(np.median(s60[test_months[i]][var])*100)/100
    m120 = round(np.median(s120[test_months[i]][var])*100)/100
    
    plt.title(str(test_months[i])+' months earlier', fontsize = 12)
    
    plt.xlabel('cancer death age', fontsize = 15)
    plt.ylabel('population density', fontsize = 15)
    # plt.legend(['sj 36m', 'sj 60m', 'sj 120m'], fontsize = 12)
    
plt.tight_layout()
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 12/12 [00:50<00:00,  4.22s/it]

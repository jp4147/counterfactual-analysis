# %%
import configs as c

from timeit import default_timer as timer

from datetime import timedelta

from datetime import datetime

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import pickle

# %% [markdown]
# ### create sine sojourn

# %%
plt.plot(np.sin(list(range(18,85)))+12)

# %%
with open('sine12.pickle', 'wb') as handle:
    pickle.dump(np.sin(list(range(18,85)))+12, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# # Run model

# %%
from model import markov
import transition_matrix as tm
import model_functions as mf

# %%
with open('var_t4t3_t2_t1_t3_t1.pickle', 'rb') as handle:
    tp = pickle.load(handle)
tmx = tm.set_transition_matrix(tp)

# %%
m0 = markov(tmx)
states_total, cases = m0.run_markov()

# %% [markdown]
# ### see results

# %%
dt1, dt2, dt3, dt4, pcmort = mf.get_incidence(np.array(states_total), cases['dt1'], cases['dt2'], cases['dt3'], cases['dt4'], cases['pcmort'])

# %%
c.target_inc.index = list(c.age_range)
c.target_inc.plot()
plt.plot(list(c.age_range), dt1,'b--')
plt.plot(list(c.age_range), dt2, color = 'orange', linestyle= '--')
plt.plot(list(c.age_range), dt3, 'g--')
plt.plot(list(c.age_range), dt4, 'r--')
plt.legend(['t1', 't2', 't3', 't4'], fontsize=15)
plt.xticks(list(range(15,85,5)))
plt.ylabel('Incidence Rate', fontsize = 20)
plt.xlabel('Age', fontsize = 20)
plt.show()

# %%
plt.plot(c.age_group, c.target_pcmort.values, 'k')
plt.plot(c.age_group, mf.grouping(pcmort), 'k:')
plt.xticks(rotation = 60)
plt.show()

# %%
plt.plot(np.array(mf.sojourn_time(tmx)))
time36 = np.array(mf.sojourn_time(tmx))
plt.plot(c.target_sojourn,'r:')
noise = np.random.normal(0, 2, time36.shape)
new_signal = time36 + noise

plt.plot(new_signal, 'k:')

# %%
# with open('time36.pickle', 'wb') as handle:
#     pickle.dump(new_signal, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
plt.plot(mf.cancer_progression(tmx))
time12 = np.array(mf.cancer_progression(tmx))
plt.plot(c.target_cancer_progression,'r:')
noise = np.random.normal(0, 2, time12.shape)
new_signal = time12 + noise
plt.plot(new_signal, 'k:')

# %%
with open('time12.pickle', 'wb') as handle:
    pickle.dump(new_signal, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# # Calibration

# %%
import configs as c

from timeit import default_timer as timer

from datetime import timedelta

from datetime import datetime

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import pickle

# %%
from calibration import sim_anneal

# %%
start = timer()
cal_markov = sim_anneal(tp_path = 'var_t4t3_t2_t1_t3_t1a.pickle', age_var = 1, model = 'mk', save = 'var_t4t3_t2_t1_t3_t1a_t1.pickle')
cal_tp = cal_markov.anneal()
end = timer()
print(f'total time: {timedelta(seconds=end-start)}')
# Out:
# 17577.220091389463
# 18120.64315245594
# 318083.0185941759
# 7.711069992789615
# 3640.8559709254814
# 15748.106805455918
# 2800.3542452135257
# 1.0 0 2800.9452506540038
# 1.0 1 2800.7223610966444
# 1.0 4 2799.7037812759913
# 0.9 25 2752.725349661004
# 0.9 26 2752.3793533441644
# 0.9 29 2752.225997702858
# 0.9 31 2752.661001663523
# 0.9 32 2752.5812264928527
# 0.9 34 2750.906427217213
# 0.9 36 2751.4955814964005
# 0.9 37 2751.4277879747456
# 0.9 38 2749.9650095571724
# 0.9 40 2749.0154426012245
# 0.9 43 2748.714717859586
# 0.9 44 2747.242122128111
# 0.9 45 2747.2091652361123
# 0.9 46 2747.3286890157615
# 0.9 50 2747.2508024427807
# 0.9 54 2747.534238024842
# 0.9 55 2747.0283960785973
# 0.9 57 2747.283156570889
# 0.9 60 2746.4217864873126
# 0.9 61 2745.1000744401426
# 0.9 63 2744.779860495057
# 0.9 64 2744.8318563710973
# 0.9 67 2741.5198864568674
# 0.9 71 2742.463746405735
# 0.9 73 2741.8080521116426
# 0.9 79 2742.5827999302933
# 0.9 80 2742.3615928906775
# 0.9 82 2736.751680665005
# 0.81 6 2737.2596749109694
# 0.81 19 2738.6683876731176
# 0.81 23 2738.090944468794
# 0.81 25 2738.81714902794
# 0.81 27 2739.590409223374
# 0.81 33 2737.769623400711
# 0.81 39 2737.6449234200904
# 0.81 50 2736.8584527713083
# 0.81 59 2738.587715051496
# 0.81 65 2737.280822088911
# 0.81 72 2732.9811191766894
# 0.81 80 2735.096657492483
# 0.81 84 2735.162525901176
# 0.81 85 2733.541099487743
# 0.81 95 2733.3040791765347
# 0.81 97 2732.4399753910257
# 0.7290000000000001 1 2729.976142106675
# 0.7290000000000001 3 2725.0368172406047
# 0.7290000000000001 17 2723.3454575431206
# 0.7290000000000001 18 2723.731096280857
# 0.7290000000000001 19 2723.738969643203
# 0.7290000000000001 26 2724.413635028356
# 0.7290000000000001 29 2724.023075782876
# 0.7290000000000001 52 2721.6156403271843
# 0.7290000000000001 59 2721.3336087255534
# 0.7290000000000001 65 2721.623154321673
# 0.7290000000000001 67 2720.344300086039
# 0.7290000000000001 73 2718.823433152354
# 0.7290000000000001 93 2718.417617608585
# 0.5904900000000002 51 2718.757575934061
# 0.5904900000000002 60 2719.034581192366
# 0.5904900000000002 71 2717.6815783237394
# 0.5904900000000002 83 2718.9485398568518
# 0.5904900000000002 85 2716.2363090016725
# 0.5904900000000002 89 2717.655379164183
# 0.5904900000000002 93 2716.9982702106545
# 0.5904900000000002 94 2716.997492502054
# 0.5904900000000002 95 2714.2143496789313
# 0.5904900000000002 97 2710.721558217535
# 0.5314410000000002 17 2710.084589245007
# 0.5314410000000002 53 2701.6821851317854
# total time: 0:17:20.356142

# %%
with open('cal_pcmort_time_pcmort_t4.pickle', 'wb') as handle:
    pickle.dump(cal_tp, handle, protocol=pickle.HIGHEST_PROTOCOL)
